# %% [markdown]
# <a href="https://colab.research.google.com/github/rakhmatherlambang/prosus-hls/blob/main/data_scraping(HLS).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# data-scraping pada sinta unila google schoolar
#
# pada page 1669 - 2502

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

base_url = "https://sinta.kemdikbud.go.id/affiliations/profile/398/?page="
view_param = "&view=googlescholar"
start_page = 1669
end_page = 2502
data_list = []

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36"
}

for page in range(start_page, end_page + 1):
    url = base_url + str(page) + view_param
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")


        articles = soup.find_all("div", class_="ar-list-item mb-5")

        for article in articles:
            title = article.find("a").text.strip() if article.find("a") else "No Title"
            link = article.find("a")["href"] if article.find("a") else "No Link"
            authors = article.find("div", class_="authors").text.strip() if article.find("div", class_="authors") else "Unknown"
            citations = article.find("span", class_="citation").text.strip() if article.find("span", class_="citation") else "0"

            data_list.append([title, link, authors, citations])

        print(f"Scraped page {page}")
        time.sleep(2)

df = pd.DataFrame(data_list, columns=["Title", "Link", "Authors", "Citations"])
df.to_csv("sinta_unila.csv", index=False)

print("Scraping selesai, data disimpan!")
# Out:
# Scraped page 1669
# Scraped page 1670
# Scraped page 1671
# Scraped page 1672
# Scraped page 1673
# Scraped page 1674
# Scraped page 1675
# Scraped page 1676
# Scraped page 1677
# Scraped page 1678
# Scraped page 1679
# Scraped page 1680
# Scraped page 1681
# Scraped page 1682
# Scraped page 1683
# Scraped page 1684
# Scraped page 1685
# Scraped page 1686
# Scraped page 1687
# Scraped page 1688
# Scraped page 1689
# Scraped page 1690
# Scraped page 1691
# Scraped page 1692
# Scraped page 1693
# Scraped page 1694
# Scraped page 1695
# Scraped page 1696
# Scraped page 1697
# Scraped page 1698
# Scraped page 1699
# Scraped page 1700
# Scraped page 1701
# Scraped page 1702
# Scraped page 1703
# Scraped page 1704
# Scraped page 1705
# Scraped page 1706
# Scraped page 1707
# Scraped page 1708
# Scraped page 1709
# Scraped page 1710
# Scraped page 1711
# Scraped page 1712
# Scraped page 1713
# Scraped page 1714
# Scraped page 1715
# Scraped page 1716
# Scraped page 1717
# Scraped page 1718
# Scraped page 1719
# Scraped page 1720
# Scraped page 1721
# Scraped page 1722
# Scraped page 1723
# Scraped page 1724
# Scraped page 1725
# Scraped page 1726
# Scraped page 1727
# Scraped page 1728
# Scraped page 1729
# Scraped page 1730
# Scraped page 1731
# Scraped page 1732
# Scraped page 1733
# Scraped page 1734
# Scraped page 1735
# Scraped page 1736
# Scraped page 1737
# Scraped page 1738
# Scraped page 1739
# Scraped page 1740
# Scraped page 1741
# Scraped page 1742
# Scraped page 1743
# Scraped page 1744
# Scraped page 1745
# Scraped page 1746
# Scraped page 1747
# Scraped page 1748
# Scraped page 1749
# Scraped page 1750
# Scraped page 1751
# Scraped page 1752
# Scraped page 1753
# Scraped page 1754
# Scraped page 1755
# Scraped page 1756
# Scraped page 1757
# Scraped page 1758
# Scraped page 1759
# Scraped page 1760
# Scraped page 1761
# Scraped page 1762
# Scraped page 1763
# Scraped page 1764
# Scraped page 1765
# Scraped page 1766
# Scraped page 1767
# Scraped page 1768
# Scraped page 1769
# Scraped page 1770
# Scraped page 1771
# Scraped page 1772
# Scraped page 1773
# Scraped page 1774
# Scraped page 1775
# Scraped page 1776
# Scraped page 1777
# Scraped page 1778
# Scraped page 1779
# Scraped page 1780
# Scraped page 1781
# Scraped page 1782
# Scraped page 1783
# Scraped page 1784
# Scraped page 1785
# Scraped page 1786
# Scraped page 1787
# Scraped page 1788
# Scraped page 1789
# Scraped page 1790
# Scraped page 1791
# Scraped page 1792
# Scraped page 1793
# Scraped page 1794
# Scraped page 1795
# Scraped page 1796
# Scraped page 1797
# Scraped page 1798
# Scraped page 1799
# Scraped page 1800
# Scraped page 1801
# Scraped page 1802
# Scraped page 1803
# Scraped page 1804
# Scraped page 1805
# Scraped page 1806
# Scraped page 1807
# Scraped page 1808
# Scraped page 1809
# Scraped page 1810
# Scraped page 1811
# Scraped page 1812
# Scraped page 1813
# Scraped page 1814
# Scraped page 1815
# Scraped page 1816
# Scraped page 1817
# Scraped page 1818
# Scraped page 1819
# Scraped page 1820
# Scraped page 1821
# Scraped page 1822
# Scraped page 1823
# Scraped page 1824
# Scraped page 1825
# Scraped page 1826
# Scraped page 1827
# Scraped page 1828
# Scraped page 1829
# Scraped page 1830
# Scraped page 1831
# Scraped page 1832
# Scraped page 1833
# Scraped page 1834
# Scraped page 1835
# Scraped page 1836
# Scraped page 1837
# Scraped page 1838
# Scraped page 1839
# Scraped page 1840
# Scraped page 1841
# Scraped page 1842
# Scraped page 1843
# Scraped page 1844
# Scraped page 1845
# Scraped page 1846
# Scraped page 1847
# Scraped page 1848
# Scraped page 1849
# Scraped page 1850
# Scraped page 1851
# Scraped page 1852
# Scraped page 1853
# Scraped page 1854
# Scraped page 1855
# Scraped page 1856
# Scraped page 1857
# Scraped page 1858
# Scraped page 1859
# Scraped page 1860
# Scraped page 1861
# Scraped page 1862
# Scraped page 1863
# Scraped page 1864
# Scraped page 1865
# Scraped page 1866
# Scraped page 1867
# Scraped page 1868
# Scraped page 1869
# Scraped page 1870
# Scraped page 1871
# Scraped page 1872
# Scraped page 1873
# Scraped page 1874
# Scraped page 1875
# Scraped page 1876
# Scraped page 1877
# Scraped page 1878
# Scraped page 1879
# Scraped page 1880
# Scraped page 1881
# Scraped page 1882
# Scraped page 1883
# Scraped page 1884
# Scraped page 1885
# Scraped page 1886
# Scraped page 1887
# Scraped page 1888
# Scraped page 1889
# Scraped page 1890
# Scraped page 1891
# Scraped page 1892
# Scraped page 1893
# Scraped page 1894
# Scraped page 1895
# Scraped page 1896
# Scraped page 1897
# Scraped page 1898
# Scraped page 1899
# Scraped page 1900
# Scraped page 1901
# Scraped page 1902
# Scraped page 1903
# Scraped page 1904
# Scraped page 1905
# Scraped page 1906
# Scraped page 1907
# Scraped page 1908
# Scraped page 1909
# Scraped page 1910
# Scraped page 1911
# Scraped page 1912
# Scraped page 1913
# Scraped page 1914
# Scraped page 1915
# Scraped page 1916
# Scraped page 1917
# Scraped page 1918
# Scraped page 1919
# Scraped page 1920
# Scraped page 1921
# Scraped page 1922
# Scraped page 1923
# Scraped page 1924
# Scraped page 1925
# Scraped page 1926
# Scraped page 1927
# Scraped page 1928
# Scraped page 1929
# Scraped page 1930
# Scraped page 1931
# Scraped page 1932
# Scraped page 1933
# Scraped page 1934
# Scraped page 1935
# Scraped page 1936
# Scraped page 1937
# Scraped page 1938
# Scraped page 1939
# Scraped page 1940
# Scraped page 1941
# Scraped page 1942
# Scraped page 1943
# Scraped page 1944
# Scraped page 1945
# Scraped page 1946
# Scraped page 1947
# Scraped page 1948
# Scraped page 1949
# Scraped page 1950
# Scraped page 1951
# Scraped page 1952
# Scraped page 1953
# Scraped page 1954
# Scraped page 1955
# Scraped page 1956
# Scraped page 1957
# Scraped page 1958
# Scraped page 1959
# Scraped page 1960
# Scraped page 1961
# Scraped page 1962
# Scraped page 1963
# Scraped page 1964
# Scraped page 1965
# Scraped page 1966
# Scraped page 1967
# Scraped page 1968
# Scraped page 1969
# Scraped page 1970
# Scraped page 1971
# Scraped page 1972
# Scraped page 1973
# Scraped page 1974
# Scraped page 1975
# Scraped page 1976
# Scraped page 1977
# Scraped page 1978
# Scraped page 1979
# Scraped page 1980
# Scraped page 1981
# Scraped page 1982
# Scraped page 1983
# Scraped page 1984
# Scraped page 1985
# Scraped page 1986
# Scraped page 1987
# Scraped page 1988
# Scraped page 1989
# Scraped page 1990
# Scraped page 1991
# Scraped page 1992
# Scraped page 1993
# Scraped page 1994
# Scraped page 1995
# Scraped page 1996
# Scraped page 1997
# Scraped page 1998
# Scraped page 1999
# Scraped page 2000
# Scraped page 2001
# Scraped page 2002
# Scraped page 2003
# Scraped page 2004
# Scraped page 2005
# Scraped page 2006
# Scraped page 2007
# Scraped page 2008
# Scraped page 2009
# Scraped page 2010
# Scraped page 2011
# Scraped page 2012
# Scraped page 2013
# Scraped page 2014
# Scraped page 2015
# Scraped page 2016
# Scraped page 2017
# Scraped page 2018
# Scraped page 2019
# Scraped page 2020
# Scraped page 2021
# Scraped page 2022
# Scraped page 2023
# Scraped page 2024
# Scraped page 2025
# Scraped page 2026
# Scraped page 2027
# Scraped page 2028
# Scraped page 2029
# Scraped page 2030
# Scraped page 2031
# Scraped page 2032
# Scraped page 2033
# Scraped page 2034
# Scraped page 2035
# Scraped page 2036
# Scraped page 2037
# Scraped page 2038
# Scraped page 2039
# Scraped page 2040
# Scraped page 2041
# Scraped page 2042
# Scraped page 2043
# Scraped page 2044
# Scraped page 2045
# Scraped page 2046
# Scraped page 2047
# Scraped page 2048
# Scraped page 2049
# Scraped page 2050
# Scraped page 2051
# Scraped page 2052
# Scraped page 2053
# Scraped page 2054
# Scraped page 2055
# Scraped page 2056
# Scraped page 2057
# Scraped page 2058
# Scraped page 2059
# Scraped page 2060
# Scraped page 2061
# Scraped page 2062
# Scraped page 2063
# Scraped page 2064
# Scraped page 2065
# Scraped page 2066
# Scraped page 2067
# Scraped page 2068
# Scraped page 2069
# Scraped page 2070
# Scraped page 2071
# Scraped page 2072
# Scraped page 2073
# Scraped page 2074
# Scraped page 2075
# Scraped page 2076
# Scraped page 2077
# Scraped page 2078
# Scraped page 2079
# Scraped page 2080
# Scraped page 2081
# Scraped page 2082
# Scraped page 2083
# Scraped page 2084
# Scraped page 2085
# Scraped page 2086
# Scraped page 2087
# Scraped page 2088
# Scraped page 2089
# Scraped page 2090
# Scraped page 2091
# Scraped page 2092
# Scraped page 2093
# Scraped page 2094
# Scraped page 2095
# Scraped page 2096
# Scraped page 2097
# Scraped page 2098
# Scraped page 2099
# Scraped page 2100
# Scraped page 2101
# Scraped page 2102
# Scraped page 2103
# Scraped page 2104
# Scraped page 2105
# Scraped page 2106
# Scraped page 2107
# Scraped page 2108
# Scraped page 2109
# Scraped page 2110
# Scraped page 2111
# Scraped page 2112
# Scraped page 2113
# Scraped page 2114
# Scraped page 2115
# Scraped page 2116
# Scraped page 2117
# Scraped page 2118
# Scraped page 2119
# Scraped page 2120
# Scraped page 2121
# Scraped page 2122
# Scraped page 2123
# Scraped page 2124
# Scraped page 2125
# Scraped page 2126
# Scraped page 2127
# Scraped page 2128
# Scraped page 2129
# Scraped page 2130
# Scraped page 2131
# Scraped page 2132
# Scraped page 2133
# Scraped page 2134
# Scraped page 2135
# Scraped page 2136
# Scraped page 2137
# Scraped page 2138
# Scraped page 2139
# Scraped page 2140
# Scraped page 2141
# Scraped page 2142
# Scraped page 2143
# Scraped page 2144
# Scraped page 2145
# Scraped page 2146
# Scraped page 2147
# Scraped page 2148
# Scraped page 2149
# Scraped page 2150
# Scraped page 2151
# Scraped page 2152
# Scraped page 2153
# Scraped page 2154
# Scraped page 2155
# Scraped page 2156
# Scraped page 2157
# Scraped page 2158
# Scraped page 2159
# Scraped page 2160
# Scraped page 2161
# Scraped page 2162
# Scraped page 2163
# Scraped page 2164
# Scraped page 2165
# Scraped page 2166
# Scraped page 2167
# Scraped page 2168
# Scraped page 2169
# Scraped page 2170
# Scraped page 2171
# Scraped page 2172
# Scraped page 2173
# Scraped page 2174
# Scraped page 2175
# Scraped page 2176
# Scraped page 2177
# Scraped page 2178
# Scraped page 2179
# Scraped page 2180
# Scraped page 2181
# Scraped page 2182
# Scraped page 2183
# Scraped page 2184
# Scraped page 2185
# Scraped page 2186
# Scraped page 2187
# Scraped page 2188
# Scraped page 2189
# Scraped page 2190
# Scraped page 2191
# Scraped page 2192
# Scraped page 2193
# Scraped page 2194
# Scraped page 2195
# Scraped page 2196
# Scraped page 2197
# Scraped page 2198
# Scraped page 2199
# Scraped page 2200
# Scraped page 2201
# Scraped page 2202
# Scraped page 2203
# Scraped page 2204
# Scraped page 2205
# Scraped page 2206
# Scraped page 2207
# Scraped page 2208
# Scraped page 2209
# Scraped page 2210
# Scraped page 2211
# Scraped page 2212
# Scraped page 2213
# Scraped page 2214
# Scraped page 2215
# Scraped page 2216
# Scraped page 2217
# Scraped page 2218
# Scraped page 2219
# Scraped page 2220
# Scraped page 2221
# Scraped page 2222
# Scraped page 2223
# Scraped page 2224
# Scraped page 2225
# Scraped page 2226
# Scraped page 2227
# Scraped page 2228
# Scraped page 2229
# Scraped page 2230
# Scraped page 2231
# Scraped page 2232
# Scraped page 2233
# Scraped page 2234
# Scraped page 2235
# Scraped page 2236
# Scraped page 2237
# Scraped page 2238
# Scraped page 2239
# Scraped page 2240
# Scraped page 2241
# Scraped page 2242
# Scraped page 2243
# Scraped page 2244
# Scraped page 2245
# Scraped page 2246
# Scraped page 2247
# Scraped page 2248
# Scraped page 2249
# Scraped page 2250
# Scraped page 2251
# Scraped page 2252
# Scraped page 2253
# Scraped page 2254
# Scraped page 2255
# Scraped page 2256
# Scraped page 2257
# Scraped page 2258
# Scraped page 2259
# Scraped page 2260
# Scraped page 2261
# Scraped page 2262
# Scraped page 2263
# Scraped page 2264
# Scraped page 2265
# Scraped page 2266
# Scraped page 2267
# Scraped page 2268
# Scraped page 2269
# Scraped page 2270
# Scraped page 2271
# Scraped page 2272
# Scraped page 2273
# Scraped page 2274
# Scraped page 2275
# Scraped page 2276
# Scraped page 2277
# Scraped page 2278
# Scraped page 2279
# Scraped page 2280
# Scraped page 2281
# Scraped page 2282
# Scraped page 2283
# Scraped page 2284
# Scraped page 2285
# Scraped page 2286
# Scraped page 2287
# Scraped page 2288
# Scraped page 2289
# Scraped page 2290
# Scraped page 2291
# Scraped page 2292
# Scraped page 2293
# Scraped page 2294
# Scraped page 2295
# Scraped page 2296
# Scraped page 2297
# Scraped page 2298
# Scraped page 2299
# Scraped page 2300
# Scraped page 2301
# Scraped page 2302
# Scraped page 2303
# Scraped page 2304
# Scraped page 2305
# Scraped page 2306
# Scraped page 2307
# Scraped page 2308
# Scraped page 2309
# Scraped page 2310
# Scraped page 2311
# Scraped page 2312
# Scraped page 2313
# Scraped page 2314
# Scraped page 2315
# Scraped page 2316
# Scraped page 2317
# Scraped page 2318
# Scraped page 2319
# Scraped page 2320
# Scraped page 2321
# Scraped page 2322
# Scraped page 2323
# Scraped page 2324
# Scraped page 2325
# Scraped page 2326
# Scraped page 2327
# Scraped page 2328
# Scraped page 2329
# Scraped page 2330
# Scraped page 2331
# Scraped page 2332
# Scraped page 2333
# Scraped page 2334
# Scraped page 2335
# Scraped page 2336
# Scraped page 2337
# Scraped page 2338
# Scraped page 2339
# Scraped page 2340
# Scraped page 2341
# Scraped page 2342
# Scraped page 2343
# Scraped page 2344
# Scraped page 2345
# Scraped page 2346
# Scraped page 2347
# Scraped page 2348
# Scraped page 2349
# Scraped page 2350
# Scraped page 2351
# Scraped page 2352
# Scraped page 2353
# Scraped page 2354
# Scraped page 2355
# Scraped page 2356
# Scraped page 2357
# Scraped page 2358
# Scraped page 2359
# Scraped page 2360
# Scraped page 2361
# Scraped page 2362
# Scraped page 2363
# Scraped page 2364
# Scraped page 2365
# Scraped page 2366
# Scraped page 2367
# Scraped page 2368
# Scraped page 2369
# Scraped page 2370
# Scraped page 2371
# Scraped page 2372
# Scraped page 2373
# Scraped page 2374
# Scraped page 2375
# Scraped page 2376
# Scraped page 2377
# Scraped page 2378
# Scraped page 2379
# Scraped page 2380
# Scraped page 2381
# Scraped page 2382
# Scraped page 2383
# Scraped page 2384
# Scraped page 2385
# Scraped page 2386
# Scraped page 2387
# Scraped page 2388
# Scraped page 2389
# Scraped page 2390
# Scraped page 2391
# Scraped page 2392
# Scraped page 2393
# Scraped page 2394
# Scraped page 2395
# Scraped page 2396
# Scraped page 2397
# Scraped page 2398
# Scraped page 2399
# Scraped page 2400
# Scraped page 2401
# Scraped page 2402
# Scraped page 2403
# Scraped page 2404
# Scraped page 2405
# Scraped page 2406
# Scraped page 2407
# Scraped page 2408
# Scraped page 2409
# Scraped page 2410
# Scraped page 2411
# Scraped page 2412
# Scraped page 2413
# Scraped page 2414
# Scraped page 2415
# Scraped page 2416
# Scraped page 2417
# Scraped page 2418
# Scraped page 2419
# Scraped page 2420
# Scraped page 2421
# Scraped page 2422
# Scraped page 2423
# Scraped page 2424
# Scraped page 2425
# Scraped page 2426
# Scraped page 2427
# Scraped page 2428
# Scraped page 2429
# Scraped page 2430
# Scraped page 2431
# Scraped page 2432
# Scraped page 2433
# Scraped page 2434
# Scraped page 2435
# Scraped page 2436
# Scraped page 2437
# Scraped page 2438
# Scraped page 2439
# Scraped page 2440
# Scraped page 2441
# Scraped page 2442
# Scraped page 2443
# Scraped page 2444
# Scraped page 2445
# Scraped page 2446
# Scraped page 2447
# Scraped page 2448
# Scraped page 2449
# Scraped page 2450
# Scraped page 2451
# Scraped page 2452
# Scraped page 2453
# Scraped page 2454
# Scraped page 2455
# Scraped page 2456
# Scraped page 2457
# Scraped page 2458
# Scraped page 2459
# Scraped page 2460
# Scraped page 2461
# Scraped page 2462
# Scraped page 2463
# Scraped page 2464
# Scraped page 2465
# Scraped page 2466
# Scraped page 2467
# Scraped page 2468
# Scraped page 2469
# Scraped page 2470
# Scraped page 2471
# Scraped page 2472
# Scraped page 2473
# Scraped page 2474
# Scraped page 2475
# Scraped page 2476
# Scraped page 2477
# Scraped page 2478
# Scraped page 2479
# Scraped page 2480
# Scraped page 2481
# Scraped page 2482
# Scraped page 2483
# Scraped page 2484
# Scraped page 2485
# Scraped page 2486
# Scraped page 2487
# Scraped page 2488
# Scraped page 2489
# Scraped page 2490
# Scraped page 2491
# Scraped page 2492
# Scraped page 2493
# Scraped page 2494
# Scraped page 2495
# Scraped page 2496
# Scraped page 2497
# Scraped page 2498
# Scraped page 2499
# Scraped page 2500
# Scraped page 2501
# Scraped page 2502
# Scraping selesai, data disimpan!

# %%
import os
os.listdir()
# Out:
# ['.config', 'sinta_unila.csv', 'sample_data']

# %%
from google.colab import files
files.download("sinta_unila.csv")

# %%
import pandas as pd
df = pd.read_csv("sinta_unila.csv")
df.head()
# Out:
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_9['Title'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_9, x='index', y='Title', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_10['Link'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_10, x='index', y='Link', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
#                                                Title  \
# 0  Structural Equality Model the Influence of Soc...
# 1  Qualitative study of local cultural wisdom and...
# 2            Journal Homepage:-www. journalijar. com
# 3  Legal Consequences for Abandoned Land Based on...
# 4  Enhancing critical thinking in elementary educ...
#
#                                                 Link  Authors  Citations
# 0  https://scholar.google.com/scholar?q=+intitle:...  Unknown          0
# 1  https://scholar.google.com/scholar?q=+intitle:...  Unknown          0
# 2  https://scholar.google.com/scholar?q=+intitle:...  Unknown          0
# 3  https://scholar.google.com/scholar?q=+intitle:...  Unknown          0
# 4  https://scholar.google.com/scholar?q=+intitle:...  Unknown          0
